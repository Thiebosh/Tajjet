# %%
import pandas as pd
df = pd.read_csv("sport.csv")
df.head(87)
df.drop(["Equipment","Exercise Type","Notes", "Modifications"], axis=1)
# Out:
#                      Exercise    Major Muscle        Minor Muscle  \
# 0                Arnold Press            Arms     Bicep,Shoulders
# 1                  Bicep Curl            Arms               Bicep
# 2              Bicycle Crunch            Core                 NaN
# 3                      Bounds  Full Body,Legs  Outer Thigh,Glutes
# 4                   Box Jumps       Full Body                 NaN
# ..                        ...             ...                 ...
# 83  Twisted Mountain Climbers  Full Body,Core             Oblique
# 84                  Wall Ball       Full Body                 NaN
# 85     Weighted Jumping Jacks       Full Body                 NaN
# 86           Weighted Punches            Core                 NaN
# 87                    Deadbug            Core                 NaN
#
#                                               Example
# 0   giphy-2.gif (https://dl.airtable.com/FvaObZ1Sy...
# 1   3e8b7121-738e-4457-b6d8-fd3a3e04de5a.gif (http...
# ...
